# %% [markdown]
# # Análise de Features com Mutual Information 🧠
#
# Este notebook demonstra como usar a classe **FeatureAnalyzer** para analisar a importância das features do dataset SVM utilizando **Mutual Information**.
#
# ## 🎯 Objetivos:
# - Carregar e preparar o dataset SVM
# - Realizar análise de Mutual Information das features
# - Configurar e testar diferentes thresholds
# - Visualizar rankings e distribuições das features
# - Selecionar as features mais relevantes
# - Integrar com DatasetManager para workflow completo

# %% [markdown]
# ## 1. Importar Bibliotecas e Configurações 📚

# %%
# Importar bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
import warnings
warnings.filterwarnings('ignore')

# Configurações de visualização
plt.style.use('default')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Adicionar diretório scripts ao path
sys.path.append('./scripts')

print("✅ Bibliotecas importadas com sucesso!")
print(f"📁 Diretório atual: {os.getcwd()}")

# Verificar arquivos disponíveis
print(f"\n🔍 Arquivos disponíveis:")
if os.path.exists('./datasets'):
    for arquivo in os.listdir('./datasets'):
        if arquivo.endswith('.csv'):
            print(f"   📊 {arquivo}")
if os.path.exists('./scripts'):
    for arquivo in os.listdir('./scripts'):
        if arquivo.endswith('.py'):
            print(f"   🐍 {arquivo}")
# Out:
# ✅ Bibliotecas importadas com sucesso!
# 📁 Diretório atual: d:\Pessoal\leopiresss\leopi\OneDrive - STJ- Superior Tribunal de Justiça\AIA\Cursos\Mestrado\Projeto Final\analise_kubemon_v2
#
# 🔍 Arquivos disponíveis:
#    📊 svm.csv
#    📊 svm_claude.csv
#    📊 terasort.csv
#    🐍 dataset_manager.py
#    🐍 feature_analyzer.py
#    🐍 lib_analise.py
#    🐍 lib_classificador.py

# %% [markdown]
# ## 2. Importar Classes Personalizadas 🔧

# %%
# Importar classes personalizadas
from feature_analyzer import FeatureAnalyzer
from dataset_manager import DatasetManager

print("✅ Classes personalizadas importadas:")
print("   🧠 FeatureAnalyzer - para análise de mutual information")
print("   📊 DatasetManager - para gerenciamento de datasets")
# Out:
# ✅ Classes personalizadas importadas:
#    🧠 FeatureAnalyzer - para análise de mutual information
#    📊 DatasetManager - para gerenciamento de datasets

# %% [markdown]
# ## 3. Carregar Dataset SVM 📂

# %%
# Carregar dataset SVM usando DatasetManager
dm = DatasetManager('svm_feature_analysis')

# Configurações para carregamento
arquivo_csv = './datasets/svm.csv'
target_column = 'target'
colunas_excluir = ['os_timestamp', 'node_name', 'iteration']

# Carregar dados
try:
    dataset = dm.carregar_dados_csv(
        arquivo_csv=arquivo_csv,
        target_column=target_column,
        colunas_excluir=colunas_excluir,
        test_size=0.3,
        val_size=0.5,
        random_state=42
    )
    
    print("\n✅ Dataset SVM carregado com sucesso!")
    
    # Informações básicas do dataset
    print(f"\n📊 Informações do Dataset:")
    print(f"   • X_train shape: {dataset['X_train'].shape}")
    print(f"   • Número de features: {len(dataset['features'])}")
    print(f"   • Classes únicas: {np.unique(dataset['y_train'])}")
    print(f"   • Distribuição das classes no treino:")
    
    unique, counts = np.unique(dataset['y_train'], return_counts=True)
    for classe, count in zip(unique, counts):
        print(f"     Classe {classe}: {count:,} ({count/len(dataset['y_train'])*100:.1f}%)")

except Exception as e:
    print(f"❌ Erro ao carregar dataset: {e}")
    # Examinar o arquivo diretamente
    print("\n📋 Examinando arquivo CSV...")
    df_temp = pd.read_csv(arquivo_csv)
    print(f"   • Shape: {df_temp.shape}")
    print(f"   • Colunas: {list(df_temp.columns)}")
    print(f"   • Primeiras linhas:")
    print(df_temp.head())
# Out:
# 🔧 Carregando dados do arquivo: ./datasets/svm.csv
# 📊 Informações do dataset:
#    • Total de registros: 80,648
#    • Total de features: 122
#    • Colunas excluídas: ['os_timestamp', 'node_name', 'iteration', 'target']
#    • Target codificado: {'interf': 0, 'normal': 1}
#
# ✅ Dados preparados:
#    • X_train shape: (56453, 122)
#    • X_val shape: (12098, 122)
#    • X_test shape: (12097, 122)
#    • Classes únicas: [0 1]
#
# ✅ Dataset SVM carregado com sucesso!
#
# 📊 Informações do Dataset:
#    • X_train shape: (56453, 122)
#    • Número de features: 122
#    • Classes únicas: [0 1]
#    • Distribuição das classes no treino:
#      Classe 0: 31,962 (56.6%)
#      Classe 1: 24,491 (43.4%)

# %% [markdown]
# ## 4. Criar Analisador de Features 🧠

# %%
# Criar instância do FeatureAnalyzer com configurações iniciais
analyzer = FeatureAnalyzer(
    threshold_mutual_info=0.005,  # Threshold baixo inicial para ver mais features
    threshold_percentile=75.0,    # Top 25% das features
    random_state=42
)

print("✅ FeatureAnalyzer criado com configurações:")
print(f"   • Threshold Mutual Info: {analyzer.threshold_mutual_info}")
print(f"   • Threshold Percentil: {analyzer.threshold_percentile}%")
print(f"   • Random State: {analyzer.random_state}")
print(f"\n🎯 Pronto para análise das features do dataset SVM!")
# Out:
# ✅ FeatureAnalyzer criado com configurações:
#    • Threshold Mutual Info: 0.005
#    • Threshold Percentil: 75.0%
#    • Random State: 42
#
# 🎯 Pronto para análise das features do dataset SVM!

# %% [markdown]
# ## 5. Executar Análise de Mutual Information 📊

# %%
# Executar análise de mutual information
print("🔬 Iniciando análise de Mutual Information...")

# Calcular mutual information usando dados de treino
resultados = analyzer.calcular_mutual_information(
    X=dm.dataset['X_train'], 
    y=dm.dataset['y_train'],
    tipo_problema='auto'  # Detecta automaticamente se é classificação ou regressão
)

print(f"\n🎉 Análise concluída com sucesso!")

# Exibir estatísticas básicas
stats = resultados['statistics']
print(f"\n📈 Estatísticas dos Mutual Information Scores:")
print(f"   • Número total de features: {stats['total_features']}")
print(f"   • Média MI: {stats['mean_mi_score']:.6f}")
print(f"   • Desvio padrão MI: {stats['std_mi_score']:.6f}")
print(f"   • Máximo MI: {stats['max_mi_score']:.6f}")
print(f"   • Mínimo MI: {stats['min_mi_score']:.6f}")

print(f"\n🎯 Thresholds aplicados:")
print(f"   • Threshold absoluto (0.005): {stats['selected_by_threshold']} features")
print(f"   • Threshold percentil 75%: {stats['selected_by_percentile']} features")
print(f"   • Critério combinado: {stats['selected_combined']} features")
# Out:
# 🔬 Iniciando análise de Mutual Information...
# 🧠 Calculando Mutual Information...
#    • Tipo de problema detectado: classification
#    • Número de features: 122
#    • Número de amostras: 56453
#    ✅ Análise concluída:
#    • Média MI: 0.0749
#    • Threshold percentil 75.0%: 0.1242
#    • Features selecionadas (combinado): 31
#
# 🎉 Análise concluída com sucesso!
#
# 📈 Estatísticas dos Mutual Information Scores:
#    • Número total de features: 122
#    • Média MI: 0.074870
#    • Desvio padrão MI: 0.120726
#    • Máximo MI: 0.656885
#    • Mínimo MI: 0.000000
#
# 🎯 Thresholds aplicados:
#    • Threshold absoluto (0.005): 69 features
#    • Threshold percentil 75%: 31 features
#    • Critério combinado: 31 features

# %% [markdown]
# ## 6. Visualizar Top Features 📈

# %%
# Plotar gráfico de barras das top features
print("📊 Gerando visualização das top features...")

# Plotar top 25 features com mutual information
analyzer.plotar_mutual_information(top_n=25, figsize=(14, 10))

print("✅ Gráfico das top features gerado!")
# Out:
# 📊 Gerando visualização das top features...
# ✅ Gráfico das top features gerado!

# %% [markdown]
# ## 7. Analisar Distribuição dos Scores 📊

# %%
# Visualizar distribuição dos mutual information scores
print("📈 Gerando visualização da distribuição dos MI scores...")

# Plotar histograma e boxplot da distribuição
analyzer.plotar_distribuicao_scores(figsize=(12, 5))

print("✅ Gráficos de distribuição gerados!")
# Out:
# 📈 Gerando visualização da distribuição dos MI scores...
# ✅ Gráficos de distribuição gerados!

# %% [markdown]
# ## 8. Relatório Detalhado da Análise 📋

# %%
# Gerar relatório completo da análise
analyzer.imprimir_relatorio()
# Out:
# 📊 RELATÓRIO DE ANÁLISE DE FEATURES - MUTUAL INFORMATION
# ======================================================================
# 🎯 Tipo de Problema: CLASSIFICATION
# 📈 Total de Features: 122
#
# 📊 Estatísticas dos MI Scores:
#    • Média: 0.074870
#    • Desvio Padrão: 0.120726
#    • Máximo: 0.656885
#    • Mínimo: 0.000000
#
# 🎯 Configuração dos Thresholds:
#    • Threshold Absolute: 0.005000
#    • Threshold Percentil 75.0%: 0.124176
#
# ✅ Features Selecionadas:
#    • Por Threshold Absolute: 69 features
#    • Por Percentil: 31 features
#    • Critério Combinado: 31 features
#
# 🏆 Top 10 Features:
#     1. ✅ mean_os_net_bytes_sent: 0.656885
#     2. ✅ mean_os_net_num_connections: 0.533648
#     3. ✅ mean_process_cpu_system: 0.409151
#     4. ✅ mean_process_disk_write_bytes: 0.393528
#     5. ✅ mean_process_disk_read_count: 0.368032
#     6. ✅ mean_process_cpu_user: 0.365441
#     7. ✅ mean_process_disk_write_count: 0.344810
#     8. ✅ mean_process_disk_read_chars: 0.324074
#     9. ✅ mean_os_net_packets_sent: 0.285425
#    10. ✅ mean_os_net_bytes_recv: 0.272297
# ======================================================================

# %% [markdown]
# ## 9. Testar Diferentes Thresholds 🎯

# %%
# Testar diferentes configurações de threshold
print("🎯 Testando diferentes configurações de thresholds...")

# Salvar configurações originais
original_mi_threshold = analyzer.threshold_mutual_info
original_percentile = analyzer.threshold_percentile

# Configurações para teste
configs_teste = [
    {'mi': 0.001, 'perc': 90.0, 'nome': 'Conservador (Top 10%)'},
    {'mi': 0.01, 'perc': 80.0, 'nome': 'Moderado (Top 20%)'},
    {'mi': 0.02, 'perc': 70.0, 'nome': 'Agressivo (Top 30%)'},
]

resultados_thresholds = []

for config in configs_teste:
    print(f"\n🔧 Testando configuração: {config['nome']}")
    
    # Atualizar thresholds
    analyzer.atualizar_thresholds(
        threshold_mutual_info=config['mi'],
        threshold_percentile=config['perc']
    )
    
    # Obter features selecionadas
    features_selecionadas = analyzer.selecionar_features_por_threshold(metodo='combined')
    
    resultados_thresholds.append({
        'nome': config['nome'],
        'mi_threshold': config['mi'],
        'percentile': config['perc'],
        'features_selecionadas': len(features_selecionadas),
        'features_list': features_selecionadas[:10]  # Primeiras 10 para exemplo
    })

# Resumo dos testes
print(f"\n📊 RESUMO DOS TESTES DE THRESHOLD:")
print("=" * 60)
for resultado in resultados_thresholds:
    print(f"{resultado['nome']}:")
    print(f"   • MI Threshold: {resultado['mi_threshold']}")
    print(f"   • Percentil: {resultado['percentile']}%")
    print(f"   • Features selecionadas: {resultado['features_selecionadas']}")
    print(f"   • Top 10: {resultado['features_list']}")
    print()

# Restaurar configurações originais
analyzer.atualizar_thresholds(
    threshold_mutual_info=original_mi_threshold,
    threshold_percentile=original_percentile
)
# Out:
# 🎯 Testando diferentes configurações de thresholds...
#
# 🔧 Testando configuração: Conservador (Top 10%)
# 🔄 Thresholds atualizados:
#    • MI Threshold: 0.001000
#    • Percentil 90.0%: 0.235589
#    • Features selecionadas: 13
# 🎯 Features selecionadas por combined: 13
#
# 🔧 Testando configuração: Moderado (Top 20%)
# 🔄 Thresholds atualizados:
#    • MI Threshold: 0.010000
#    • Percentil 80.0%: 0.151051
#    • Features selecionadas: 25
# 🎯 Features selecionadas por combined: 25
#
# 🔧 Testando configuração: Agressivo (Top 30%)
# 🔄 Thresholds atualizados:
#    • MI Threshold: 0.020000
#    • Percentil 70.0%: 0.085573
#    • Features selecionadas: 37
# 🎯 Features selecionadas por combined: 37
#
# 📊 RESUMO DOS TESTES DE THRESHOLD:
# ============================================================
# Conservador (Top 10%):
#    • MI Threshold: 0.001
#    • Percentil: 90.0%
#    • Features selecionadas: 13
#    • Top 10: ['mean_os_net_bytes_sent', 'mean_os_net_num_connections', 'mean_process_cpu_system', 'mean_process_disk_write_bytes', 'mean_process_disk_read_count', 'mean_process_cpu_user', 'mean_process_disk_write_count', 'mean_process_disk_read_chars', 'mean_os_net_packets_sent', 'mean_os_net_bytes_recv']
#
# Moderado (Top 20%):
#    • MI Threshold: 0.01
#    • Percentil: 80.0%
#    • Features selecionadas: 25
#    • Top 10: ['mean_os_net_bytes_sent', 'mean_os_net_num_connections', 'mean_process_cpu_system', 'mean_process_disk_write_bytes', 'mean_process_disk_read_count', 'mean_process_cpu_user', 'mean_process_disk_write_count', 'mean_process_disk_read_chars', 'mean_os_net_packets_sent', 'mean_os_net_bytes_recv']
#
# Agressivo (Top 30%):
#    • MI Threshold: 0.02
#    • Percentil: 70.0%
#    • Features selecionadas: 37
#    • Top 10: ['mean_os_net_bytes_sent', 'mean_os_net_num_connections', 'mean_process_cpu_system', 'mean_process_disk_write_bytes', 'mean_process_disk_read_count', 'mean_process_cpu_user', 'mean_process_disk_write_count', 'mean_process_disk_read_chars', 'mean_os_net_packets_sent', 'mean_os_net_bytes_recv']
#
# 🔄 Thresholds atualizados:
#    • MI Threshold: 0.005000
#    • Percentil 75.0%: 0.124176
#    • Features selecionadas: 31

# %% [markdown]
# ## 10. Seleção de Features por Ranking 🏆

# %%
# Testar seleção por ranking (top N features)
print("🏆 Testando seleção por ranking (Top N features)...")

# Testar diferentes números de top features
numeros_features = [5, 10, 15, 20, 30, 50]

for n in numeros_features:
    top_features = analyzer.selecionar_top_features(n)
    print(f"\n🎯 Top {n} features selecionadas")

# Obter ranking completo como DataFrame
print(f"\n📊 Obtendo ranking completo das features...")
ranking_df = analyzer.get_feature_ranking()

print(f"✅ Ranking obtido com {len(ranking_df)} features")
print(f"\n🏆 Top 15 Features detalhadas:")
print(ranking_df[['feature', 'mutual_info_score', 'rank', 'selected_combined']].head(15).to_string(index=False))

# Estatísticas do ranking
print(f"\n📈 Estatísticas do Ranking:")
print(f"   • Features com MI > 0.01: {(ranking_df['mutual_info_score'] > 0.01).sum()}")
print(f"   • Features com MI > 0.02: {(ranking_df['mutual_info_score'] > 0.02).sum()}")
print(f"   • Features com MI > 0.05: {(ranking_df['mutual_info_score'] > 0.05).sum()}")
print(f"   • Mediana MI Score: {ranking_df['mutual_info_score'].median():.6f}")
# Out:
# 🏆 Testando seleção por ranking (Top N features)...
# 🏆 Top 5 features selecionadas:
#     1. mean_os_net_bytes_sent: 0.6569
#     2. mean_os_net_num_connections: 0.5336
#     3. mean_process_cpu_system: 0.4092
#     4. mean_process_disk_write_bytes: 0.3935
#     5. mean_process_disk_read_count: 0.3680
#
# 🎯 Top 5 features selecionadas
# 🏆 Top 10 features selecionadas:
#     1. mean_os_net_bytes_sent: 0.6569
#     2. mean_os_net_num_connections: 0.5336
#     3. mean_process_cpu_system: 0.4092
#     4. mean_process_disk_write_bytes: 0.3935
#     5. mean_process_disk_read_count: 0.3680
#     6. mean_process_cpu_user: 0.3654
#     7. mean_process_disk_write_count: 0.3448
#     8. mean_process_disk_read_chars: 0.3241
#     9. mean_os_net_packets_sent: 0.2854
#    10. mean_os_net_bytes_recv: 0.2723
#
# 🎯 Top 10 features selecionadas
# 🏆 Top 15 features selecionadas:
#     1. mean_os_net_bytes_sent: 0.6569
#     2. mean_os_net_num_connections: 0.5336
#     3. mean_process_cpu_system: 0.4092
#     4. mean_process_disk_write_bytes: 0.3935
#     5. mean_process_disk_read_count: 0.3680
#     6. mean_process_cpu_user: 0.3654
#     7. mean_process_disk_write_count: 0.3448
#     8. mean_process_disk_read_chars: 0.3241
#     9. mean_os_net_packets_sent: 0.2854
#    10. mean_os_net_bytes_recv: 0.2723
#    11. mean_process_disk_write_chars: 0.2588
#    12. mean_process_net_rx_bytes: 0.2399
#    13. mean_container_mem_cache: 0.2371
#    14. mean_os_net_packets_recv: 0.2223
#    15. mean_os_cpu_system: 0.2064
#
# 🎯 Top 15 features selecionadas
# 🏆 Top 20 features selecionadas:
#     1. mean_os_net_bytes_sent: 0.6569
#     2. mean_os_net_num_connections: 0.5336
#     3. mean_process_cpu_system: 0.4092
#     4. mean_process_disk_write_bytes: 0.3935
#     5. mean_process_disk_read_count: 0.3680
#     6. mean_process_cpu_user: 0.3654
#     7. mean_process_disk_write_count: 0.3448
#     8. mean_process_disk_read_chars: 0.3241
#     9. mean_os_net_packets_sent: 0.2854
#    10. mean_os_net_bytes_recv: 0.2723
#    11. mean_process_disk_write_chars: 0.2588
#    12. mean_process_net_rx_bytes: 0.2399
#    13. mean_container_mem_cache: 0.2371
#    14. mean_os_net_packets_recv: 0.2223
#    15. mean_os_cpu_system: 0.2064
#    16. mean_os_cpu_ctx_switches: 0.1937
#    17. mean_os_cpu_interrupts: 0.1873
#    18. mean_process_net_tx_bytes: 0.1858
#    19. mean_os_cpu_soft_interrupts: 0.1762
#    20. mean_process_mem_resident: 0.1636
#
# 🎯 Top 20 features selecionadas
# 🏆 Top 30 features selecionadas:
#     1. mean_os_net_bytes_sent: 0.6569
#     2. mean_os_net_num_connections: 0.5336
#     3. mean_process_cpu_system: 0.4092
#     4. mean_process_disk_write_bytes: 0.3935
#     5. mean_process_disk_read_count: 0.3680
#     6. mean_process_cpu_user: 0.3654
#     7. mean_process_disk_write_count: 0.3448
#     8. mean_process_disk_read_chars: 0.3241
#     9. mean_os_net_packets_sent: 0.2854
#    10. mean_os_net_bytes_recv: 0.2723
#    11. mean_process_disk_write_chars: 0.2588
#    12. mean_process_net_rx_bytes: 0.2399
#    13. mean_container_mem_cache: 0.2371
#    14. mean_os_net_packets_recv: 0.2223
#    15. mean_os_cpu_system: 0.2064
#    16. mean_os_cpu_ctx_switches: 0.1937
#    17. mean_os_cpu_interrupts: 0.1873
#    18. mean_process_net_tx_bytes: 0.1858
#    19. mean_os_cpu_soft_interrupts: 0.1762
#    20. mean_process_mem_resident: 0.1636
#    21. mean_container_mem_pgfault: 0.1635
#    22. mean_os_mem_pgreuse: 0.1592
#    23. mean_container_mem_inactive_file: 0.1545
#    24. mean_os_mem_nr_inactive_file: 0.1525
#    25. mean_os_mem_pgfree: 0.1512
#    26. mean_container_net_tx_bytes: 0.1504
#    27. mean_process_mem_data: 0.1451
#    28. mean_process_net_tx_packets: 0.1306
#    29. mean_os_mem_pgfault: 0.1256
#    30. mean_container_net_rx_bytes: 0.1245
#
# 🎯 Top 30 features selecionadas
# 🏆 Top 50 features selecionadas:
#     1. mean_os_net_bytes_sent: 0.6569
#     2. mean_os_net_num_connections: 0.5336
#     3. mean_process_cpu_system: 0.4092
#     4. mean_process_disk_write_bytes: 0.3935
#     5. mean_process_disk_read_count: 0.3680
#     6. mean_process_cpu_user: 0.3654
#     7. mean_process_disk_write_count: 0.3448
#     8. mean_process_disk_read_chars: 0.3241
#     9. mean_os_net_packets_sent: 0.2854
#    10. mean_os_net_bytes_recv: 0.2723
#    11. mean_process_disk_write_chars: 0.2588
#    12. mean_process_net_rx_bytes: 0.2399
#    13. mean_container_mem_cache: 0.2371
#    14. mean_os_net_packets_recv: 0.2223
#    15. mean_os_cpu_system: 0.2064
#    16. mean_os_cpu_ctx_switches: 0.1937
#    17. mean_os_cpu_interrupts: 0.1873
#    18. mean_process_net_tx_bytes: 0.1858
#    19. mean_os_cpu_soft_interrupts: 0.1762
#    20. mean_process_mem_resident: 0.1636
#    21. mean_container_mem_pgfault: 0.1635
#    22. mean_os_mem_pgreuse: 0.1592
#    23. mean_container_mem_inactive_file: 0.1545
#    24. mean_os_mem_nr_inactive_file: 0.1525
#    25. mean_os_mem_pgfree: 0.1512
#    26. mean_container_net_tx_bytes: 0.1504
#    27. mean_process_mem_data: 0.1451
#    28. mean_process_net_tx_packets: 0.1306
#    29. mean_os_mem_pgfault: 0.1256
#    30. mean_container_net_rx_bytes: 0.1245
#    31. mean_container_mem_pgpgout: 0.1242
#    32. mean_os_cpu_softirq: 0.1241
#    33. mean_os_cpu_user: 0.1221
#    34. mean_process_net_rx_packets: 0.1121
#    35. mean_os_cpu_idle: 0.1052
#    36. mean_container_mem_pgpgin: 0.0977
#    37. mean_container_net_rx_packets: 0.0858
#    38. mean_container_net_tx_packets: 0.0850
#    39. mean_os_mem_nr_mapped: 0.0729
#    40. mean_os_disk_write_sectors: 0.0622
#    41. mean_os_mem_pgpgout: 0.0611
#    42. mean_os_disk_write_io: 0.0598
#    43. mean_container_cpu_user: 0.0547
#    44. mean_container_cpu_system: 0.0481
#    45. mean_container_mem_mapped_file: 0.0304
#    46. mean_container_mem_active_file: 0.0287
#    47. mean_container_mem_rss: 0.0279
#    48. mean_container_mem_inactive_anon: 0.0277
#    49. mean_os_disk_write_ticks: 0.0274
#    50. mean_os_disk_time_in_queue: 0.0258
#
# 🎯 Top 50 features selecionadas
#
# 📊 Obtendo ranking completo das features...
# ✅ Ranking obtido com 122 features
#
# 🏆 Top 15 Features detalhadas:
#                       feature  mutual_info_score  rank  selected_combined
#        mean_os_net_bytes_sent           0.656885     1               True
#   mean_os_net_num_connections           0.533648     2               True
#       mean_process_cpu_system           0.409151     3               True
# mean_process_disk_write_bytes           0.393528     4               True
#  mean_process_disk_read_count           0.368032     5               True
#         mean_process_cpu_user           0.365441     6               True
# mean_process_disk_write_count           0.344810     7               True
#  mean_process_disk_read_chars           0.324074     8               True
#      mean_os_net_packets_sent           0.285425     9               True
#        mean_os_net_bytes_recv           0.272297    10               True
# mean_process_disk_write_chars           0.258844    11               True
#     mean_process_net_rx_bytes           0.239932    12               True
#      mean_container_mem_cache           0.237062    13               True
#      mean_os_net_packets_recv           0.222337    14               True
#            mean_os_cpu_system           0.206449    15               True
#
# 📈 Estatísticas do Ranking:
#    • Features com MI > 0.01: 61
#    • Features com MI > 0.02: 51
#    • Features com MI > 0.05: 43
#    • Mediana MI Score: 0.010006

# %% [markdown]
# ## 11. Integração com DatasetManager 🔄

# %%
# Testar integração do FeatureAnalyzer com DatasetManager
print("🔄 Testando integração FeatureAnalyzer + DatasetManager...")

# Criar novo DatasetManager para teste da integração
dm_integracao = DatasetManager('svm_integracao_teste')

# Carregar dados novamente
dm_integracao.carregar_dados_csv(
    arquivo_csv='./datasets/svm.csv',
    target_column='target',
    colunas_excluir=['os_timestamp', 'node_name', 'iteration']
)

# Usar método integrado para análise de features
print(f"\n🧠 Executando análise integrada...")
resultados_integrados = dm_integracao.analisar_features_mutual_information(
    threshold_mutual_info=0.01,
    threshold_percentile=80.0,
    aplicar_selecao=True,  # Aplicar seleção automaticamente
    metodo_selecao='combined'
)

print(f"\n✅ Análise integrada concluída!")
print(f"📊 Informações após seleção automática:")
dm_integracao.imprimir_informacoes()

# Comparar shapes antes e depois da seleção
print(f"\n📈 Comparação de shapes:")
print(f"   • Dataset original - Features: {len(dm.dataset['features'])}")
print(f"   • Dataset com seleção - Features: {len(dm_integracao.dataset['features'])}")
print(f"   • Redução: {len(dm.dataset['features']) - len(dm_integracao.dataset['features'])} features")
print(f"   • Percentual mantido: {len(dm_integracao.dataset['features'])/len(dm.dataset['features'])*100:.1f}%")
# Out:
# 🔄 Testando integração FeatureAnalyzer + DatasetManager...
# 🔧 Carregando dados do arquivo: ./datasets/svm.csv
# 📊 Informações do dataset:
#    • Total de registros: 80,648
#    • Total de features: 122
#    • Colunas excluídas: ['os_timestamp', 'node_name', 'iteration', 'target']
#    • Target codificado: {'interf': 0, 'normal': 1}
#
# ✅ Dados preparados:
#    • X_train shape: (48388, 122)
#    • X_val shape: (16130, 122)
#    • X_test shape: (16130, 122)
#    • Classes únicas: [0 1]
#
# 🧠 Executando análise integrada...
# 🧠 Iniciando análise de features com Mutual Information...
# 🧠 Calculando Mutual Information...
#    • Tipo de problema detectado: classification
#    • Número de features: 122
#    • Número de amostras: 48388
#    ✅ Análise concluída:
#    • Média MI: 0.0744
#    • Threshold percentil 80.0%: 0.1510
#    • Features selecionadas (combinado): 25
# 🎯 Features selecionadas por combined: 25
# 🎯 Aplicando seleção automática de features...
# 🎯 Aplicando seleção de features: 25 features
#    ✅ Seleção aplicada:
#    • Novo shape X_train: (48388, 25)
#    • Features selecionadas: 25
#    ✅ 25 features selecionadas aplicadas ao dataset
#
# ✅ Análise integrada concluída!
# 📊 Informações após seleção automática:
#
# 📊 Informações do Dataset: svm_integracao_teste
# ==================================================
# Nome do dataset: svm_integracao_teste
# X_train.shape: (48388, 25)
# X_val.shape: (16130, 25)
# X_test.shape: (16130, 25)
# y_train length: 48388
# y_val length: 16130
# y_test length: 16130
# X_train_scaled.shape: None
# X_val_scaled.shape: None
# X_test_scaled.shape: None
# Features count: 25
# Scaler type: None
# Classes mapping: {'interf': 0, 'normal': 1}
# ==================================================
#
# 📈 Comparação de shapes:
#    • Dataset original - Features: 122
#    • Dataset com seleção - Features: 25
#    • Redução: 97 features
#    • Percentual mantido: 20.5%

# %% [markdown]
# ## 12. Relatório Final e Conclusões 📋

# %%
# Relatório final e demonstração da nova funcionalidade de ranges
print("📋 RELATÓRIO FINAL - ANÁLISE COMPLETA DE FEATURES")
print("=" * 70)

# Usar o analisador já existente para demonstrar a nova funcionalidade
print("\n🎯 Nova Funcionalidade: Análise por Ranges de Importância")

# Executar análise por ranges
analyzer.imprimir_analise_ranges()

print(f"\n📊 Testando seleção por categorias:")

# Selecionar features de alta importância
features_alta_importancia = analyzer.selecionar_features_por_categoria(['Alta', 'Muito Alta'])

# Selecionar features de importância moderada ou superior
features_moderada_superior = analyzer.selecionar_features_por_categoria(['Moderada', 'Alta', 'Muito Alta'])

# Selecionar apenas features de importância muito alta (se houver)
features_muito_alta = analyzer.selecionar_features_por_categoria(['Muito Alta'])

print(f"\n🎯 Recomendações de Uso:")
print(f"   • Para modelos simples: Use features de categoria 'Alta' e 'Muito Alta' ({len(features_alta_importancia)} features)")
print(f"   • Para modelos robustos: Use features 'Moderada' ou superior ({len(features_moderada_superior)} features)")
print(f"   • Para máxima performance: Foque nas features 'Muito Alta' ({len(features_muito_alta)} features)")

print(f"\n✅ Análise de features por ranges implementada com sucesso!")
print(f"📈 Ranges definidos:")
print(f"   • Muito Baixa: [0.0 - 0.001)")
print(f"   • Baixa: [0.001 - 0.01)")
print(f"   • Moderada: [0.01 - 0.05)")
print(f"   • Alta: [0.05 - 0.1)")
print(f"   • Muito Alta: [0.1 - ∞)")

print(f"\n🎉 Demonstração completa finalizada!")
print("=" * 70)
# Out:
# 📋 RELATÓRIO FINAL - ANÁLISE COMPLETA DE FEATURES
# ======================================================================
#
# 🎯 Nova Funcionalidade: Análise por Ranges de Importância
#
# 🎯 ANÁLISE DE FEATURES POR RANGES DE IMPORTÂNCIA
# ======================================================================
# 📊 Definição dos Ranges:
#    • Muito Baixa: [0.0 - 0.001)
#    • Baixa: [0.001 - 0.01)
#    • Moderada: [0.01 - 0.05)
#    • Alta: [0.05 - 0.1)
#    • Muito Alta: [0.1 - ∞)
#
# 📈 Distribuição das Features por Categoria:
#
# 🔶 Muito Baixa:
#    • Quantidade: 33 features (27.0%)
#    • Range: [0.0 - 0.001)
#    • Scores: 0.000000 - 0.000949
#    • Média: 0.000163 (±0.000283)
#    • Exemplos: mean_process_net_tx_colls, mean_os_cpu_guest_nice, mean_os_disk_read_merge, mean_container_net_rx_frame, mean_container_net_rx_drop ...
#
# 🔶 Baixa:
#    • Quantidade: 28 features (23.0%)
#    • Range: [0.001 - 0.01)
#    • Scores: 0.001013 - 0.009991
#    • Média: 0.003738 (±0.002489)
#    • Exemplos: mean_process_mem_size, mean_container_disk_8:0_total, mean_os_mem_nr_active_anon, mean_container_disk_8:0_write, mean_container_disk_8:0_async ...
#
# 🔶 Moderada:
#    • Quantidade: 18 features (14.8%)
#    • Range: [0.01 - 0.05)
#    • Scores: 0.010021 - 0.048124
#    • Média: 0.020868 (±0.010034)
#    • Exemplos: mean_container_cpu_system, mean_container_mem_mapped_file, mean_container_mem_active_file, mean_container_mem_rss, mean_container_mem_inactive_anon ...
#
# 🔶 Alta:
#    • Quantidade: 8 features (6.6%)
#    • Range: [0.05 - 0.1)
#    • Scores: 0.054715 - 0.097702
#    • Média: 0.072401 (±0.015509)
#    • Exemplos: mean_container_mem_pgpgin, mean_container_net_rx_packets, mean_container_net_tx_packets, mean_os_mem_nr_mapped, mean_os_disk_write_sectors ...
#
# 🔶 Muito Alta:
#    • Quantidade: 35 features (28.7%)
#    • Range: [0.1 - inf)
#    • Scores: 0.105225 - 0.656885
#    • Média: 0.230551 (±0.126942)
#    • Exemplos: mean_os_net_bytes_sent, mean_os_net_num_connections, mean_process_cpu_system, mean_process_disk_write_bytes, mean_process_disk_read_count ...
#
# 📊 Resumo Estatístico:
#    • Total de features analisadas: 122
#    • Features de importância Moderada ou superior: 61
#    • Recomendação: Focar nas features de categoria 'Alta' e 'Muito Alta'
# ======================================================================
#
# 📊 Testando seleção por categorias:
# 🎯 Features selecionadas das categorias ['Alta', 'Muito Alta']:
#    • Total: 43 features
#    • Alta: 8 features
#    • Muito Alta: 35 features
# 🎯 Features selecionadas das categorias ['Moderada', 'Alta', 'Muito Alta']:
#    • Total: 61 features
#    • Moderada: 18 features
#    • Alta: 8 features
#    • Muito Alta: 35 features
# 🎯 Features selecionadas das categorias ['Muito Alta']:
#    • Total: 35 features
#    • Muito Alta: 35 features
#
# 🎯 Recomendações de Uso:
#    • Para modelos simples: Use features de categoria 'Alta' e 'Muito Alta' (43 features)
#    • Para modelos robustos: Use features 'Moderada' ou superior (61 features)
#    • Para máxima performance: Foque nas features 'Muito Alta' (35 features)
#
# ✅ Análise de features por ranges implementada com sucesso!
# 📈 Ranges definidos:
#    • Muito Baixa: [0.0 - 0.001)
#    • Baixa: [0.001 - 0.01)
#    • Moderada: [0.01 - 0.05)
#    • Alta: [0.05 - 0.1)
#    • Muito Alta: [0.1 - ∞)
#
# 🎉 Demonstração completa finalizada!
# ======================================================================

# %% [markdown]
# ## 13. Visualizações da Análise por Ranges 📊

# %%
# Plotar visualizações da análise por ranges
print("📊 Gerando visualizações da análise por ranges de importância...")

# Plotar análise por ranges (4 gráficos: barras, pizza, histograma, boxplot)
analyzer.plotar_analise_ranges(figsize=(16, 12))

print("✅ Visualizações da análise por ranges geradas!")
print("\n📈 Os gráficos mostram:")
print("   • Distribuição de features por categoria de importância")
print("   • Percentuais de cada categoria")
print("   • Histograma dos scores colorido por categoria")
print("   • Boxplot comparativo entre categorias")
print("\n💡 Use essas visualizações para:")
print("   • Identificar rapidamente features importantes")
print("   • Compreender a distribuição da importância no dataset")
print("   • Tomar decisões informadas sobre seleção de features")
# Out:
# 📊 Gerando visualizações da análise por ranges de importância...
# ✅ Visualizações da análise por ranges geradas!
#
# 📈 Os gráficos mostram:
#    • Distribuição de features por categoria de importância
#    • Percentuais de cada categoria
#    • Histograma dos scores colorido por categoria
#    • Boxplot comparativo entre categorias
#
# 💡 Use essas visualizações para:
#    • Identificar rapidamente features importantes
#    • Compreender a distribuição da importância no dataset
#    • Tomar decisões informadas sobre seleção de features

# %%
# Gerar relatório final completo
print("📋 RELATÓRIO FINAL DA ANÁLISE DE FEATURES")
print("=" * 70)

# Usar método integrado para relatório
dm_integracao.imprimir_relatorio_features()

# Resumo das principais descobertas
print(f"\n🎯 PRINCIPAIS DESCOBERTAS:")
print("=" * 50)

# Obter ranking das features integradas
ranking_final = dm_integracao.get_feature_ranking()

# Top 10 features mais importantes
top_10_final = ranking_final.head(10)

print(f"\n🏆 TOP 10 FEATURES MAIS IMPORTANTES (por Mutual Information):")
for i, row in top_10_final.iterrows():
    status = "✅ SELECIONADA" if row['selected_combined'] else "❌ NÃO SELECIONADA"
    print(f"   {row['rank']:2d}. {row['feature']:30s} | MI: {row['mutual_info_score']:.6f} | {status}")

# Estatísticas finais
print(f"\n📊 ESTATÍSTICAS FINAIS:")
print(f"   • Total de features analisadas: {len(ranking_final)}")
print(f"   • Features selecionadas (método combinado): {ranking_final['selected_combined'].sum()}")
print(f"   • Percentual de redução: {(1 - ranking_final['selected_combined'].sum()/len(ranking_final))*100:.1f}%")
print(f"   • MI score médio das selecionadas: {ranking_final[ranking_final['selected_combined']]['mutual_info_score'].mean():.6f}")
print(f"   • MI score médio das não selecionadas: {ranking_final[~ranking_final['selected_combined']]['mutual_info_score'].mean():.6f}")

print(f"\n✅ ANÁLISE DE FEATURES CONCLUÍDA COM SUCESSO!")
print(f"🎉 O FeatureAnalyzer está pronto para uso em projetos de ML!")

# Salvar dataset com features selecionadas
arquivo_final = dm_integracao.salvar_dataset('./datasets/svm_features_selecionadas.pkl')
print(f"\n💾 Dataset com features selecionadas salvo em: {arquivo_final}")
# Out:
# 📋 RELATÓRIO FINAL DA ANÁLISE DE FEATURES
# ======================================================================
#
# 📊 RELATÓRIO DE ANÁLISE DE FEATURES - MUTUAL INFORMATION
# ======================================================================
# 🎯 Tipo de Problema: CLASSIFICATION
# 📈 Total de Features: 122
#
# 📊 Estatísticas dos MI Scores:
#    • Média: 0.074420
#    • Desvio Padrão: 0.120609
#    • Máximo: 0.658256
#    • Mínimo: 0.000000
#
# 🎯 Configuração dos Thresholds:
#    • Threshold Absolute: 0.010000
#    • Threshold Percentil 80.0%: 0.151021
#
# ✅ Features Selecionadas:
#    • Por Threshold Absolute: 58 features
#    • Por Percentil: 25 features
#    • Critério Combinado: 25 features
#
# 🏆 Top 10 Features:
#     1. ✅ mean_os_net_bytes_sent: 0.658256
#     2. ✅ mean_os_net_num_connections: 0.534539
#     3. ✅ mean_process_cpu_system: 0.407896
#     4. ✅ mean_process_disk_write_bytes: 0.394040
#     5. ✅ mean_process_cpu_user: 0.363498
#     6. ✅ mean_process_disk_read_count: 0.362243
#     7. ✅ mean_process_disk_write_count: 0.346691
#     8. ✅ mean_process_disk_read_chars: 0.322347
#     9. ✅ mean_os_net_packets_sent: 0.289194
#    10. ✅ mean_os_net_bytes_recv: 0.270810
# ======================================================================
#
# 🎯 PRINCIPAIS DESCOBERTAS:
# ==================================================
#
# 🏆 TOP 10 FEATURES MAIS IMPORTANTES (por Mutual Information):
#     1. mean_os_net_bytes_sent         | MI: 0.658256 | ✅ SELECIONADA
#     2. mean_os_net_num_connections    | MI: 0.534539 | ✅ SELECIONADA
#     3. mean_process_cpu_system        | MI: 0.407896 | ✅ SELECIONADA
#     4. mean_process_disk_write_bytes  | MI: 0.394040 | ✅ SELECIONADA
#     5. mean_process_cpu_user          | MI: 0.363498 | ✅ SELECIONADA
#     6. mean_process_disk_read_count   | MI: 0.362243 | ✅ SELECIONADA
#     7. mean_process_disk_write_count  | MI: 0.346691 | ✅ SELECIONADA
#     8. mean_process_disk_read_chars   | MI: 0.322347 | ✅ SELECIONADA
#     9. mean_os_net_packets_sent       | MI: 0.289194 | ✅ SELECIONADA
#    10. mean_os_net_bytes_recv         | MI: 0.270810 | ✅ SELECIONADA
#
# 📊 ESTATÍSTICAS FINAIS:
#    • Total de features analisadas: 122
#    • Features selecionadas (método combinado): 25
#    • Percentual de redução: 79.5%
#    • MI score médio das selecionadas: 0.271497
#    • MI score médio das não selecionadas: 0.023627
#
# ✅ ANÁLISE DE FEATURES CONCLUÍDA COM SUCESSO!
# 🎉 O FeatureAnalyzer está pronto para uso em projetos de ML!
# ✅ Dataset salvo com sucesso em ./datasets/svm_features_selecionadas.pkl
#
# 💾 Dataset com features selecionadas salvo em: ./datasets/svm_features_selecionadas.pkl
